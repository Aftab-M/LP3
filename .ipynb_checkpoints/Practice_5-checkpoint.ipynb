# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sales_data_sample.csv', encoding='unicode escape')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
df = df.drop(columns=['CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2', 'CONTACTFIRSTNAME', 'CONTACTLASTNAME', 'QTR_ID', 'CITY', 'STATE', 'TERRITORY', 'PHONE'])

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0   2/24/2003 0:00  Shipped         2     2003  Motorcycles    95    S10_1678
# 1    5/7/2003 0:00  Shipped         5     2003  Motorcycles    95    S10_1678
# 2    7/1/2003 0:00  Shipped         7     2003  Motorcycles    95    S10_1678
# 3   8/25/2003 0:00  Shipped         8     2003  Motorcycles    95    S10_1678
# 4  10/10/2003 0:00  Shipped        10     2003  Motorcycles    95    S10_1678
#
#   POSTALCODE COUNTRY DEALSIZE
# 0      10022     USA    Small
# ...

# %%
df = df.drop(columns=['ORDERDATE', 'STATUS', 'YEAR_ID', 'MONTH_ID', 'ORDERNUMBER'])

# %%
df = df.drop(columns=['POSTALCODE'])

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  PRODUCTLINE  MSRP  \
# 0               30      95.70                2  2871.00  Motorcycles    95
# 1               34      81.35                5  2765.90  Motorcycles    95
# 2               41      94.74                2  3884.34  Motorcycles    95
# 3               45      83.26                6  3746.70  Motorcycles    95
# 4               49     100.00               14  5205.27  Motorcycles    95
#
#   PRODUCTCODE COUNTRY DEALSIZE
# 0    S10_1678     USA    Small
# 1    S10_1678  France    Small
# 2    S10_1678  France   Medium
# 3    S10_1678     USA   Medium
# 4    S10_1678     USA   Medium

# %%
df.dtypes
# Out:
# QUANTITYORDERED      int64
# PRICEEACH          float64
# ORDERLINENUMBER      int64
# SALES              float64
# PRODUCTLINE         object
# MSRP                 int64
# PRODUCTCODE         object
# COUNTRY             object
# DEALSIZE            object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

def convert_cats(col):
    df[col] = encoder.fit_transform(df[col].values)

# %%
cols = ['PRODUCTLINE', 'PRODUCTCODE', 'COUNTRY', 'DEALSIZE']

# %%
for col in cols:
    convert_cats(col)

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  PRODUCTLINE  MSRP  \
# 0               30      95.70                2  2871.00            1    95
# 1               34      81.35                5  2765.90            1    95
# 2               41      94.74                2  3884.34            1    95
# 3               45      83.26                6  3746.70            1    95
# 4               49     100.00               14  5205.27            1    95
#
#    PRODUCTCODE  COUNTRY  DEALSIZE
# 0            0       18         2
# 1            0        6         2
# 2            0        6         1
# 3            0       18         1
# 4            0       18         1

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df = scaler.fit_transform(df)

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1, 16):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)

# %%
print(wcss)
# Out:
# [25406.999999999993, 18581.407734730175, 16429.74046583554, 15204.784834603803, 13991.08272892264, 13292.79735290932, 12351.080701529536, 11913.5713330556, 11398.844928218523, 10978.25544163288, 10628.363627723538, 10336.311307022652, 9905.670566050465, 9703.83909795323, 9454.25859647298]

# %%
k = list(range(1,16))

plt.figure()
plt.xlabel('k value')
plt.ylabel('inertia')
# plt.grid()
plt.plot(k, wcss)
plt.show()

# %%
# sampledf = df[['QUANTITYORDERED', 'PRICEEACH']]

sdf = pd.read_csv('sales_data_sample.csv', encoding='unicode escape')
sdf = sdf[['QUANTITYORDERED', 'PRICEEACH']]
sdf.isna().sum()

sdf = scaler.fit_transform(sdf)
sdf
# Out:
# array([[-0.52289086,  0.5969775 ],
#        [-0.11220131, -0.11445035],
#        [ 0.60650538,  0.54938372],
#        ...,
#        [ 0.81185016,  0.81015797],
#        [-0.11220131, -1.06186404],
#        [ 1.2225397 , -0.89925195]])

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, random_state=10, n_init=10)
clusters = kmeans.fit_predict(sdf)

# %%
plt.scatter(sdf[:,0], sdf[:,1], c=clusters, cmap='viridis')
