# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sales_data_sample.csv", encoding='unicode_escape')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.shape
# Out:
# (2823, 25)

# %%
df['TERRITORY'].head()
# Out:
# 0     NaN
# 1    EMEA
# 2    EMEA
# 3     NaN
# 4     NaN
# Name: TERRITORY, dtype: object

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
df = df.drop(columns=['ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'TERRITORY', 'PHONE', 'STATE', 'CONTACTFIRSTNAME', 'CONTACTLASTNAME', 'POSTALCODE', 'ORDERNUMBER', 'CUSTOMERNAME'])

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES        ORDERDATE  \
# 0               30      95.70                2  2871.00   2/24/2003 0:00
# 1               34      81.35                5  2765.90    5/7/2003 0:00
# 2               41      94.74                2  3884.34    7/1/2003 0:00
# 3               45      83.26                6  3746.70   8/25/2003 0:00
# 4               49     100.00               14  5205.27  10/10/2003 0:00
#
#     STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP PRODUCTCODE COUNTRY  \
# 0  Shipped       1         2     2003  Motorcycles    95    S10_1678     USA
# 1  Shipped       2         5     2003  Motorcycles    95    S10_1678  France
# 2  Shipped       3         7     2003  Motorcycles    95    S10_1678  France
# 3  Shipped       3         8     2003  Motorcycles    95    S10_1678     USA
# 4  Shipped       4        10     2003  Motorcycles    95    S10_1678     USA
#
#   DEALSIZE
# 0    Small
# 1    Small
# 2   Medium
# 3   Medium
# ...

# %%
df.isna().sum()
# Out:
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# ORDERDATE          0
# STATUS             0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# PRODUCTLINE        0
# MSRP               0
# PRODUCTCODE        0
# COUNTRY            0
# DEALSIZE           0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# QUANTITYORDERED      int64
# PRICEEACH          float64
# ORDERLINENUMBER      int64
# SALES              float64
# ORDERDATE           object
# STATUS              object
# QTR_ID               int64
# MONTH_ID             int64
# YEAR_ID              int64
# PRODUCTLINE         object
# MSRP                 int64
# PRODUCTCODE         object
# COUNTRY             object
# DEALSIZE            object
# dtype: object

# %%
for col in df.columns.values:
    print(f'\n\n================================================================For the column {col}')
    print(df[col].value_counts())
# Out:
# ================================================================For the column QUANTITYORDERED
# QUANTITYORDERED
# 34    112
# 21    103
# 46    101
# 27    100
# 31     97
# 41     97
# 45     97
# 26     96
# 29     94
# 48     94
# 25     94
# 20     93
# 33     92
# 22     92
# 32     91
# 24     91
# 38     91
# 49     91
# 36     89
# 44     89
# 37     87
# 43     85
# 39     84
# 28     82
# 40     78
# 42     76
# 30     75
# 23     73
# 35     71
# 47     70
# 50     65
# 55     16
# 66      5
# 15      4
# 51      4
# 61      3
# 18      3
# 60      3
# 76      3
# 59      3
# 56      3
# 19      3
# 64      3
# 10      2
# 6       2
# 11      2
# 54      2
# 70      2
# 97      1
# 85      1
# 62      1
# 52      1
# 16      1
# 13      1
# 58      1
# 65      1
# 12      1
# 77      1
# Name: count, dtype: int64
#
#
# ================================================================For the column PRICEEACH
# PRICEEACH
# 100.00    1304
# 59.87        6
# 96.34        6
# ...

# %%
# df = df.drop(columns = ['ORDERDATE', 'STATUS','YEAR_ID', 'QTR_ID', 'MONTH_ID'])

df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  PRODUCTLINE  MSRP  \
# 0               30      95.70                2  2871.00  Motorcycles    95
# 1               34      81.35                5  2765.90  Motorcycles    95
# 2               41      94.74                2  3884.34  Motorcycles    95
# 3               45      83.26                6  3746.70  Motorcycles    95
# 4               49     100.00               14  5205.27  Motorcycles    95
#
#   PRODUCTCODE COUNTRY DEALSIZE
# 0    S10_1678     USA    Small
# 1    S10_1678  France    Small
# 2    S10_1678  France   Medium
# 3    S10_1678     USA   Medium
# 4    S10_1678     USA   Medium

# %%
df.dtypes
# Out:
# QUANTITYORDERED      int64
# PRICEEACH          float64
# ORDERLINENUMBER      int64
# SALES              float64
# PRODUCTLINE         object
# MSRP                 int64
# PRODUCTCODE         object
# COUNTRY             object
# DEALSIZE            object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
def convert_cats(col):
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].values)

# %%
cols = ['PRODUCTLINE', 'PRODUCTCODE', 'COUNTRY', 'DEALSIZE']

for col in cols:
    convert_cats(col)

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  PRODUCTLINE  MSRP  \
# 0               30      95.70                2  2871.00            1    95
# 1               34      81.35                5  2765.90            1    95
# 2               41      94.74                2  3884.34            1    95
# 3               45      83.26                6  3746.70            1    95
# 4               49     100.00               14  5205.27            1    95
#
#    PRODUCTCODE  COUNTRY  DEALSIZE
# 0            0       18         2
# 1            0        6         2
# 2            0        6         1
# 3            0       18         1
# 4            0       18         1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaled_df = scaler.fit_transform(df)

# %%
from sklearn.cluster import KMeans

wcss = []

for k in range(1,15):
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state = 15)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)

# %%
k = list(range(1,15))

plt.plot(k, wcss)

plt.xlabel('Clusters')
plt.ylabel('Scores')
plt.title('Finding the correct number of clusters w/ Elbow point method')
plt.grid()
plt.show()

# %%
# AT K=4, THE GRAPH STARTS TO MOVE ALMOST PARALLEL TO X-AXIS
# THIS MEANS THAT IT IS THE OPTIMAL NUMBER OF CLUSTERS FOR THIS DATASET
